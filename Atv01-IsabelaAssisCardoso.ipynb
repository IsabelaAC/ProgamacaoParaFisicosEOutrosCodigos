# %%
######################################################
#    FIS616 Introdução à Computação em Física
#
#                   01/2020
#
#           
#           
#           Prof. V.B. Nascimento
#                   @UFMG
#
#  
# Referência: 
#  Numerical Python: Scientific Computing and 
#  Data Science Applications with Numpy, SciPy
#  and Matplotlib
#                2nd Edition
#             Robert Johansson
######################################################

######################################################
#
#               Atividade Avaliativa 01 
#       "Chapter 4 - Plotting and Visualization"
#              Visualização de Gráficos 
######################################################


#                   MATPLOTLIB (Pyplot)
# Visualização de gráficos 2D e 3D de alta qualidade 
# usando a biblioteca Matplotlib (www.matplotlib.org)
#

# %%
######################################################################################################
# ALUNO : Isabela Assis Cardoso 
# MATRÍCULA : 2017019091
# TURMA : TM
######################################################################################################

# %%
import matplotlib as mpl 
import matplotlib.pyplot as plt
import numpy as np
import sympy

# %%
# 1) Faça um gráfico da função y = (1/x^2) * sen(3*x), assim como de suas derivadas de ordem um e dois. (2.0 pontos)
####################################################################################################################

x = np.linspace(1, 5, 1000)
y1 = (1/x**2)*np.sin(3*x)
y2 = (3*np.cos(3*x)/x**2)-(2*np.sin(3*x)/x**3)
y3 = (3*(2*np.sin(3*x)-(3*x*np.cos(3*x)))/x**4)-((9*x*np.sin(3*x)+3*np.cos(3*x))/x**3)

plt.plot(x, y1, label = 'y(x)')
plt.plot(x, y2, label = 'y\'(x)')
plt.plot(x, y3, label = 'y\'\'(x)')
plt.legend()
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# 2) Através de análise gráfica localize as raízes de x**3-x**2+1 = x+2.  
# Faça um gráfico mostrando, via um "inset", uma das raízes. (2.0 pontos)
####################################################################################################################

fig = plt.figure(figsize=(10,5)) 

def f(x):
    return x**3-x**2-x-1
def g(x):
  return y==0

def plot_and_format_axes(ax, x, f, g, fontsize):
    ax.plot(x, f(x), color='g', label= "$f(x)$")
    ax.plot(x, g(x), color='r', label= "$g(x)$")
    ax.xaxis.set_major_locator(mpl.ticker.MaxNLocator(6))
    ax.yaxis.set_major_locator(mpl.ticker.MaxNLocator(5))
    ax.set_xlabel(r"$x$", fontsize=fontsize)
    ax.set_ylabel(r"$f(x)$", fontsize=fontsize)

ax = fig.add_axes([0.3, 0.3, 0.8, 0.8], facecolor="#f5f5f5")
x = np.linspace(-5,5,1000)
plot_and_format_axes(ax, x, f, g, 18)

x0, x1 = 1.6, 2
ax.axvline(x0, ymax=.8, c = 'b', ls = ":")
ax.axvline(x1, ymax=.8, c = 'b', ls = ":")

ax_insert = fig.add_axes([0.75, 0.40, 0.30, 0.30], facecolor='none')
x_insert = np.linspace(x0, x1, 1000)
plot_and_format_axes(ax_insert, x_insert, f, g, 14)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-8ca2660db441> in <module>
#      20 ax = fig.add_axes([0.3, 0.3, 0.8, 0.8], facecolor="#f5f5f5")
#      21 x = np.linspace(-5,5,1000)
# ---> 22 plot_and_format_axes(ax, x, f, g, 18)
#      23
#      24 x0, x1 = 1.6, 2
#
# <ipython-input-11-8ca2660db441> in plot_and_format_axes(ax, x, f, g, fontsize)
#      12 def plot_and_format_axes(ax, x, f, g, fontsize):
#      13     ax.plot(x, f(x), color='g', label= "$f(x)$")
# ---> 14     ax.plot(x, g(x), color='r', label= "$g(x)$")
#      15     ax.xaxis.set_major_locator(mpl.ticker.MaxNLocator(6))
#      16     ax.yaxis.set_major_locator(mpl.ticker.MaxNLocator(5))
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1741         """
#    1742         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1743         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1744         for line in lines:
#    1745             self.add_line(line)
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     271                 this += args[0],
#     272                 args = args[1:]
# --> 273             yield from self._plot_args(this, kwargs)
#     274
#     275     def get_next_color(self):
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     397
#     398         if x.shape[0] != y.shape[0]:
# --> 399             raise ValueError(f"x and y must have same first dimension, but "
#     400                              f"have shapes {x.shape} and {y.shape}")
#     401         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (1000,) and (100,)

# %%
# 3) Faça gráficos 3D de z = sen(x)^2 * (3*y - 3)**2 do tipo "surface", "wireplot" e "contour". O gráfico deverá ser no intervalo
# -10 < x < 10 e -10 < y < 10. (2.0 pontos)
####################################################################################################################
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import mpl_toolkits.mplot3d 

fig, axes = plt.subplots(1, 3, figsize=(14, 4), subplot_kw={'projection': '3d'})

def title_and_labels(ax, title):
    ax.set_title(title)
    ax.set_xlabel("$x$", fontsize=16)
    ax.set_ylabel("$y$", fontsize=16)
    ax.set_zlabel("$z$", fontsize=16)   
    
x = y = np.linspace(-10, 10 ,50 )
X, Y = np.meshgrid(x, y)

Z = (np.sin(X)**2)*(3*Y-3)**2

norm = mpl.colors.Normalize(-abs(Z).max(), abs(Z).max())

p = axes[0].plot_surface(X, Y, Z, rstride=1, cstride=1,linewidth=0, antialiased=False, norm=norm, cmap=mpl.cm.Blues)

cb = fig.colorbar(p, ax=axes[0], shrink=0.6)
                  
title_and_labels(axes[0], "plot_surface")
                  
p = axes[1].plot_wireframe(X, Y, Z, rstride=2, cstride=2,color="darkgrey")
                  
title_and_labels(axes[1], "plot_wireframe")

cset = axes[2].contour(X, Y, Z, zdir='z', offset=0, norm=norm, cmap=mpl.cm.Blues)

cset = axes[2].contour(X, Y, Z, zdir='y', offset=3, norm=norm, cmap=mpl.cm.Blues)

title_and_labels(axes[2], "contour")
plt.show()

# %%
# 4) Faça um gráfico tipo contour plot da função de Rosenbrock: f(x,y) = (a - x)**2 + b(y - x**2)**2 com a = 1 e b = 100. 
# O intervalo será de -3 < x < 3  e -3 < y < 3. (2.0 pontos)
###################################################################################################################
import matplotlib as mpl 
import matplotlib.pyplot as plt
import numpy as np

x = y = np.linspace(-3, 3, 150)
X, Y = np.meshgrid(x, y)
a = 1
b = 2
Z = (a - X)**2 + b*(Y - X**2)**2
fig, ax = plt.subplots(figsize=(6, 5))
norm = mpl.colors.Normalize(-abs(Z).max(), abs(Z).max())
p = ax.pcolor(X, Y, Z, norm=norm, cmap=mpl.cm.bwr)
ax.axis('tight')
ax.set_xlabel(r"$x$", fontsize=18)
ax.set_ylabel(r"$y$", fontsize=18)
ax.xaxis.set_major_locator(mpl.ticker.MaxNLocator(4))
ax.yaxis.set_major_locator(mpl.ticker.MaxNLocator(4))
cb = fig.colorbar(p, ax=ax)
cb.set_label(r"$z$", fontsize=18)

plt.show()
# Out:
# <ipython-input-7-579780a82deb>:15: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   p = ax.pcolor(X, Y, Z, norm=norm, cmap=mpl.cm.bwr)

# %%
# 5) Faça um gráfico tipo "surface" da função de Rosenbrock: f(x,y) = (a - x)**2 + b(y - x**2)**2 com a = 1 e b = 100. 
# O intervalo será de -3 < x < 3  e -3 < y < 3. (2.0 pontos)
###################################################################################################################
import matplotlib as mpl 
import matplotlib.pyplot as plt
import numpy as np
import mpl_toolkits.mplot3d 

fig = plt.Figure()
ax = plt.axes(projection = '3d')
    
x = y = np.linspace(-3, 3, 100)
X, Y = np.meshgrid(x, y)

a = 1
b = 100
Z = (a - X)**2 + b*(Y - X**2)**2

ax.plot_surface(X,Y,Z)
plt.show()
